# %%
# %pip install jupyter_http_over_ws
# !jupyter server extension enable --py jupyter_http_over_ws

# %%
# Start a local notebook server for Colab over websocket.
# Use a temporary token and do not reuse it across sessions.
# !jupyter notebook --NotebookApp.allow_origin='https://colab.research.google.com' --port=8888 --NotebookApp.token='colab1234' --NotebookApp.password='' --NotebookApp.port_retries=0

# %%
# !jupyter server list
# !jupyter notebook stop 8888
# !jupyter server stop 8888
